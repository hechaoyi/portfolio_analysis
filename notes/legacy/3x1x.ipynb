# %%
# %pylab inline
from app.analysis import Quote
bonds = Quote.screen_funds('Bonds', 'Domestic', 'Government', 'Long-Term')
growth = Quote.screen_funds('Equities', 'Domestic', 'Large-Cap', 'Growth')
blend = Quote.screen_funds('Equities', 'Domestic', 'Large-Cap', 'Blend', min_assets=10)
print(len(bonds), len(growth), len(blend))
quote = Quote(bonds + growth + blend + ['TMF', 'SPXL'], 50, 5)
print(f'from {quote.start.date()} to {quote.end.date()} - {len(quote.data.columns)}')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 6 16 14
# from 2019-09-03 to 2019-11-11 - 38

# %%
stats = quote.statistics()
assert stats[stats['len'] < stats['len'].max()].empty
stats = stats[stats['shrp'] > 0]
print(len(stats))
stats.sort_values('mean', ascending=False)
# Out:
# 28
#          len      mean       std      skew      shrp      yield   drawdown
# Symbols
# SPXL      46  0.275010  0.771339 -0.542390  0.347275  18.860191  11.682070
# QQQ       46  0.129650  0.307831 -0.261997  0.397968   8.464997   4.558731
# ONEQ      46  0.120211  0.318206 -0.431328  0.355329   7.845931   4.762262
# RSP       46  0.114132  0.318953 -0.372085  0.335438   7.138821   4.892349
# VOO       46  0.102985  0.257074 -0.559563  0.372820   6.547207   3.911321
# IVV       46  0.102664  0.257894 -0.531368  0.370390   6.584459   3.965209
# SPY       46  0.102392  0.256978 -0.555601  0.370652   6.550180   3.949604
# ITOT      46  0.101828  0.267904 -0.615916  0.353431   6.573917   4.173491
# SCHB      46  0.101713  0.268343 -0.559866  0.352422   6.515956   4.149239
# QUAL      46  0.101185  0.253193 -0.110641  0.371424   6.648406   3.767877
# VTI       46  0.100642  0.266436 -0.557228  0.350926   6.415001   4.125909
# SCHX      46  0.099843  0.256288 -0.576852  0.361703   6.450988   3.940836
# VV        46  0.099808  0.257226 -0.539354  0.360246   6.435278   3.971540
# IWB       46  0.099397  0.257387 -0.551896  0.358427   6.388249   4.000031
# IWY       46  0.083883  0.256437 -0.096297  0.299256   5.765118   4.096995
# SCHG      46  0.080319  0.262577 -0.267341  0.278686   5.681067   4.183509
# VONG      46  0.072170  0.254248 -0.128676  0.255762   5.315840   4.206625
# IWF       46  0.070690  0.256624 -0.126344  0.247627   5.229552   4.305088
# MGK       46  0.069182  0.264569 -0.207687  0.234491   5.273857   4.342892
# VUG       46  0.061486  0.258342 -0.200789  0.210355   4.776403   4.282000
# FV        46  0.046309  0.275116 -0.468634  0.142361   3.328525   4.901952
# IUSG      46  0.043574  0.236487 -0.336561  0.154052   3.670628   4.125496
# SPYG      46  0.042572  0.237886 -0.275029  0.148933   3.558039   4.154495
# VOOG      46  0.042477  0.235880 -0.261088  0.149799   3.539899   4.141452
# IVW       46  0.041988  0.237174 -0.258958  0.146917   3.540047   4.167756
# RPG       46  0.031367  0.239462 -0.485585  0.101160   2.842255   4.708222
# VIG       46  0.025408  0.193145 -0.450322  0.094567   2.654690   3.469634
# JKE       46  0.014741  0.283793 -0.036643  0.026774   2.381305   5.522097

# %%
quote.setup_mask(stats.index)
sd = quote.optimize_portfolio()
quote.setup_mask(['VGLT', 'MGK'])
sd.update(quote.optimize_portfolio())
quote.setup_mask(['TMF', 'SPXL'])
sd.update(quote.optimize_portfolio())
quote.setup_mask({e for r in sd.values() for e in r})
sd.update(quote.optimize_portfolio())
for e in sd:
    print(e, sd[e])
_, ratio = sd.peekitem()
quote.setup_mask(ratio)
quote.graph(ratio)
# Out:
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'RSP', 'VOO', 'SCHB', 'SPY', 'IVW', 'VV', 'SPYG', 'VOOG', 'MGK', 'JKE', 'VUG', 'IUSG', 'ONEQ', 'QQQ', 'FV', 'SCHG', 'VONG', 'RPG', 'IWY', 'VIG', 'SCHX'] at 0.905/-0.51 - 0.371
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'RSP', 'VOO', 'SCHB', 'SPY', 'IVW', 'VV', 'SPYG', 'VOOG', 'MGK', 'JKE', 'VUG', 'IUSG', 'ONEQ', 'QQQ', 'FV', 'SCHG', 'VONG', 'RPG', 'IWY', 'VIG', 'SCHX'] at 0.910/-0.52 - 0.371
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'RSP', 'VOO', 'SCHB', 'SPY', 'IVW', 'VV', 'SPYG', 'VOOG', 'MGK', 'JKE', 'VUG', 'IUSG', 'ONEQ', 'QQQ', 'FV', 'SCHG', 'VONG', 'RPG', 'IWY', 'VIG', 'SCHX'] at 0.915/-0.53 - 0.371
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'RSP', 'VOO', 'SCHB', 'SPY', 'IVW', 'VV', 'SPYG', 'VOOG', 'MGK', 'JKE', 'VUG', 'IUSG', 'ONEQ', 'QQQ', 'FV', 'SCHG', 'VONG', 'RPG', 'IWY', 'VIG', 'SCHX'] at 0.920/-0.54 - 0.371
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'RSP', 'VOO', 'SCHB', 'SPY', 'IVW', 'VV', 'SPYG', 'VOOG', 'MGK', 'JKE', 'VUG', 'IUSG', 'ONEQ', 'QQQ', 'FV', 'SCHG', 'VONG', 'RPG', 'IWY', 'VIG', 'SCHX'] at 0.925/-0.55 - 0.371
# evicted RPG 0.923 0.874
# evicted IWY 0.924 0.877
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'RSP', 'VOO', 'SCHB', 'SPY', 'IVW', 'VV', 'SPYG', 'VOOG', 'MGK', 'JKE', 'VUG', 'IUSG', 'ONEQ', 'QQQ', 'FV', 'SCHG', 'VONG', 'VIG', 'SCHX'] at 0.930/-0.56 - 0.371
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'VOO', 'SPY', 'IVW', 'SPYG', 'MGK', 'RSP', 'SCHB', 'VV', 'JKE', 'VUG', 'IUSG', 'VOOG', 'ONEQ', 'FV', 'VIG', 'SCHG', 'VONG', 'SCHX', 'QUAL'] at 0.935/-0.57 - 0.398
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'VOO', 'SPY', 'IVW', 'SPYG', 'MGK', 'RSP', 'SCHB', 'VV', 'JKE', 'VUG', 'IUSG', 'VOOG', 'ONEQ', 'FV', 'VIG', 'SCHG', 'VONG', 'SCHX', 'QUAL'] at 0.940/-0.58 - 0.398
# evicted VIG 0.936 0.834
# retry backlogs ['IVV', 'IWF', 'IWB', 'ITOT', 'VTI', 'SPXL', 'VOO', 'SPY', 'IVW', 'SPYG', 'MGK', 'RSP', 'SCHB', 'VV', 'JKE', 'VUG', 'IUSG', 'VOOG', 'ONEQ', 'FV', 'SCHG', 'VONG', 'SCHX', 'QUAL'] at 0.945/-0.59 - 0.398
# evicted QUAL 0.944 0.944
# retry backlogs ['IVV', 'IWF', 'ITOT', 'SPXL', 'VOO', 'VTI', 'IVW', 'SPY', 'VV', 'MGK', 'SPYG', 'VOOG', 'JKE', 'RSP', 'SCHB', 'VUG', 'ONEQ', 'IWB', 'IUSG', 'FV', 'SCHG', 'VONG', 'SCHX'] at 0.950/-0.60 - 0.398
# evicted VONG 0.903 0.903
# retry backlogs ['IVV', 'IWF', 'ITOT', 'SPXL', 'VOO', 'VTI', 'IVW', 'SPYG', 'MGK', 'SPY', 'VOOG', 'VV', 'JKE', 'RSP', 'SCHB', 'ONEQ', 'IWB', 'QQQ', 'VUG', 'FV', 'SCHG', 'IUSG'] at 0.955/-0.61 - 0.362
# evicted IWF 0.900 0.900
# retry backlogs ['IVV', 'ITOT', 'SPXL', 'VTI', 'IVW', 'VOO', 'SPY', 'SPYG', 'MGK', 'VV', 'RSP', 'JKE', 'SCHB', 'ONEQ', 'IWB', 'IUSG', 'QQQ', 'FV', 'VUG', 'SCHG', 'VOOG'] at 0.960/-0.62 - 0.362
# evicted RSP 0.959 0.654
# evicted FV 0.958 0.907
# evicted SCHX 0.938 0.938
# retry backlogs ['IVV', 'ITOT', 'SPXL', 'VTI', 'IVW', 'VOO', 'SPY', 'SPYG', 'MGK', 'VV', 'SCHB', 'JKE', 'ONEQ', 'IUSG', 'IWB', 'VUG', 'VOOG', 'SCHG'] at 0.965/-0.63 - 0.398
# evicted VOO 0.932 0.932
# retry backlogs ['IVV', 'ITOT', 'SPXL', 'IVW', 'SCHB', 'VTI', 'VV', 'JKE', 'ONEQ', 'IWB', 'IUSG', 'SPY', 'SPYG', 'VUG', 'VOOG', 'MGK', 'SCHG'] at 0.970/-0.64 - 0.398
# evicted SPY 0.932 0.932
# retry backlogs ['ITOT', 'SPXL', 'IVV', 'IVW', 'VTI', 'SCHB', 'VV', 'JKE', 'ONEQ', 'IWB', 'IUSG', 'SPYG', 'VUG', 'VOOG', 'MGK', 'SCHG'] at 0.975/-0.65 - 0.398
# evicted SCHG 0.971 0.927
# evicted IWB 0.939 0.939
# retry backlogs ['IVW', 'SPXL', 'VTI', 'SCHB', 'ITOT', 'IVV', 'VV', 'JKE', 'ONEQ', 'IUSG', 'SPYG', 'VUG', 'VOOG', 'MGK'] at 0.980/-0.66 - 0.398
# evicted MGK 0.964 0.901
# evicted IVV 0.932 0.932
# retry backlogs ['ITOT', 'SPXL', 'SCHB', 'JKE', 'IVW', 'ONEQ', 'VTI', 'IUSG', 'SPYG', 'VV', 'VOOG', 'VUG'] at 0.985/-0.67 - 0.398
# evicted JKE 0.981 0.830
# evicted ONEQ 0.983 0.918
# evicted VUG 0.955 0.915
# evicted VV 0.940 0.940
# retry backlogs ['ITOT', 'SPXL', 'IVW', 'SCHB', 'SPYG', 'VTI', 'IUSG', 'VOOG'] at 0.990/-0.68 - 0.398
# evicted VOOG 0.930 0.904
# evicted ITOT 0.927 0.927
# retry backlogs ['IUSG', 'IVW', 'SPYG', 'VTI', 'SCHB', 'SPXL'] at 0.995/-0.69 - 0.398
# evicted IVW 0.930 0.907
# evicted VTI 0.928 0.928
# retry backlogs ['IUSG', 'SCHB', 'SPYG', 'SPXL'] at 1.000/-0.70 - 0.398
# evicted IUSG 0.998 0.915
# evicted SPYG 0.932 0.904
# evicted SPXL 0.997 0.929
# evicted SCHB 0.929 0.929
# evicted VGLT -0.457 -0.457
# retry backlogs ['TMF'] at 0.905/-0.51 - 0.347
# /Users/che/.local/share/virtualenvs/portfolio_analysis-cXHJLPF2/lib/python3.7/site-packages/scipy/optimize/optimize.py:1795: RuntimeWarning: invalid value encountered in double_scalars
#   p = (xf - fulc) * q - (xf - nfc) * r
# /Users/che/.local/share/virtualenvs/portfolio_analysis-cXHJLPF2/lib/python3.7/site-packages/scipy/optimize/optimize.py:1796: RuntimeWarning: invalid value encountered in double_scalars
#   q = 2.0 * (q - r)
# retry backlogs ['TMF'] at 0.910/-0.52 - 0.347
# retry backlogs ['TMF'] at 0.915/-0.53 - 0.347
# retry backlogs ['TMF'] at 0.920/-0.54 - 0.347
# retry backlogs ['TMF'] at 0.925/-0.55 - 0.347
# retry backlogs ['TMF'] at 0.930/-0.56 - 0.347
# retry backlogs ['TMF'] at 0.935/-0.57 - 0.347
# retry backlogs ['TMF'] at 0.940/-0.58 - 0.347
# retry backlogs ['TMF'] at 0.945/-0.59 - 0.347
# retry backlogs ['TMF'] at 0.950/-0.60 - 0.347
# retry backlogs ['TMF'] at 0.955/-0.61 - 0.347
# retry backlogs ['TMF'] at 0.960/-0.62 - 0.347
# retry backlogs ['TMF'] at 0.965/-0.63 - 0.347
# retry backlogs ['TMF'] at 0.970/-0.64 - 0.347
# retry backlogs ['TMF'] at 0.975/-0.65 - 0.347
# retry backlogs ['TMF'] at 0.980/-0.66 - 0.347
# evicted TMF -0.659 -0.659
# retry backlogs ['MGK', 'SPXL'] at 0.905/-0.51 - 0.398
# retry backlogs ['MGK', 'SPXL'] at 0.910/-0.52 - 0.398
# retry backlogs ['MGK', 'SPXL'] at 0.915/-0.53 - 0.398
# retry backlogs ['MGK', 'SPXL'] at 0.920/-0.54 - 0.398
# retry backlogs ['MGK', 'SPXL'] at 0.925/-0.55 - 0.398
# retry backlogs ['MGK', 'SPXL'] at 0.930/-0.56 - 0.398
# evicted SPXL 0.929 0.929
# retry backlogs ['MGK'] at 0.935/-0.57 - 0.398
# retry backlogs ['MGK'] at 0.940/-0.58 - 0.398
# retry backlogs ['MGK'] at 0.945/-0.59 - 0.398
# retry backlogs ['MGK'] at 0.950/-0.60 - 0.398
# retry backlogs ['MGK'] at 0.955/-0.61 - 0.398
# retry backlogs ['MGK'] at 0.960/-0.62 - 0.398
# retry backlogs ['MGK'] at 0.965/-0.63 - 0.398
# evicted MGK 0.964 0.964
# (0.234, 0.234, 0.069) {'MGK': 1}
# (0.347, 0.347, 0.275) {'SPXL': 1}
# (0.398, 0.398, 0.13) {'QQQ': 1}
#            count     mean       std      min       25%       50%       75%  \
# QQQ         46.0  0.12965  0.307831 -0.63974 -0.080697  0.193209  0.334373
# Portfolio   46.0  0.12965  0.307831 -0.63974 -0.080697  0.193209  0.334373
#
#                 max      shrp     yield  drawdown  skewness
# QQQ        0.858479  0.397968  8.464997  4.558731 -0.261997
# Portfolio  0.858479  0.397968  8.464997  4.558731 -0.261997

# %%
quote.setup_mask(['MGK', 'VGLT'])
quote.graph({'MGK': 0.6, 'VGLT': 0.4})
# Out:
#            count      mean       std       min       25%       50%       75%  \
# MGK         46.0  0.078594  0.268048 -0.656389 -0.106093  0.116005  0.250674
# Portfolio   46.0 -0.005062  0.177347 -0.528197 -0.119876 -0.003140  0.131056
# VGLT        46.0 -0.136482  0.460084 -1.268470 -0.458351 -0.085591  0.253760
#
#                 max      shrp     yield  drawdown  skewness
# MGK        0.758771  0.266560  4.442971  4.342892 -0.287172
# Portfolio  0.315201 -0.068817 -0.392611  3.028140 -0.442535
# VGLT       0.744884 -0.312171 -7.645983  7.862873 -0.343484

# %%
quote.setup_mask(['SPXL', 'TMF'])
quote.graph({'SPXL': 0.6, 'TMF': 0.4})
# Out:
#            count      mean       std       min       25%       50%       75%  \
# SPXL        46.0  0.301249  0.784339 -1.927525 -0.242821  0.533240  0.774608
# Portfolio   46.0  0.026085  0.407420 -1.055136 -0.220051  0.049110  0.327851
# TMF         46.0 -0.461980  1.419143 -3.964844 -1.413764 -0.275491  0.681863
#
#                 max      shrp      yield   drawdown  skewness
# SPXL       2.079508  0.374974  17.425467  11.682070 -0.584238
# Portfolio  0.889972  0.046494   0.950790   7.357513 -0.347079
# TMF        2.254943 -0.330567 -23.761224  24.254975 -0.354618
