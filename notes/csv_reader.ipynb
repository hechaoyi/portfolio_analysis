# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
csv = pd.read_csv('../1.csv', index_col=0, parse_dates=['time'])

# %%
csv.plot(figsize=(15, 5), grid=1)
