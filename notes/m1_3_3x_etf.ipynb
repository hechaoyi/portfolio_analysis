# %%
from app.analysis import Quote
horizon, period = 120, 21
quote = Quote(['TMF', 'UPRO', 'TLT', 'VOO'], horizon)

# %%
quote.statistics(period)
# Out:
#          21-len   21-mean    21-std   21-shrp   drawdown
# Symbols
# TLT          64  2.748956  2.365765  1.091524   3.224333
# TMF          64  7.870484  7.349487  1.048211   9.589677
# VOO          64  1.158140  3.166263  0.313137   6.639516
# UPRO         64  2.842798  9.538686  0.280556  19.546274

# %%
quote.setup_mask(['TMF', 'UPRO'])
quote.find_optimal_ratio(period, 5)
# Out:
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# ({'TMF': 0.59, 'UPRO': 0.41}, 5.792, 4.1787)

# %%
# %pylab inline
quote.setup_mask(['TMF', 'UPRO'])
quote.graph(period, {'TMF': 0.59, 'UPRO': 0.41})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std        min       25%       50%  \
# Portfolio   64.0  5.676028  4.278723  -0.258445  1.968007  4.367814
# TMF         64.0  7.870484  7.349487  -8.068232  2.202805  8.388560
# UPRO        64.0  2.842798  9.538686 -17.186617 -4.582351  5.711493
#
#                  75%        max      shrp   drawdown
# Portfolio   9.535037  14.717516  1.287618   2.960654
# TMF        13.960121  23.599407  1.048211   9.589677
# UPRO        9.791164  16.996327  0.280556  19.546274

# %%
quote.setup_mask(['TLT', 'VOO'])
quote.find_optimal_ratio(period, 2)

# %%
# %pylab inline
quote.setup_mask(['TLT', 'VOO'])
quote.graph(period, {'TLT': 0.58, 'VOO': 0.42})
