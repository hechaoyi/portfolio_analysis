# %%
from app.analysis import Quote
horizon, period = 120, 21
quote = Quote(['TMF', 'SPXL', 'EDV', 'VUG', 'VGLT', 'VOO'], horizon)

# %%
quote.statistics(period)
# Out:
#          21-len   21-mean    21-std   21-shrp   drawdown
# Symbols
# VGLT         62  2.630217  2.335788  1.054698   3.096044
# EDV          62  3.525348  3.246951  1.034411   4.608950
# TMF          62  7.607841  7.315098  1.017235   9.589677
# VUG          62  1.478650  3.777936  0.347275   8.023383
# VOO          62  1.125795  3.212175  0.298591   6.639516
# SPXL         62  2.816064  9.707736  0.272916  19.502869

# %%
quote.setup_mask(['TMF', 'SPXL'])
quote.find_optimal_ratio(period, 5)
# Out:
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ({'TMF': 0.59, 'SPXL': 0.41}, 5.6553, 4.1126)

# %%
# %pylab inline
quote.setup_mask(['TMF', 'SPXL'])
quote.graph(period, {'TMF': 0.59, 'SPXL': 0.41})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std        min       25%       50%  \
# Portfolio   62.0  5.518244  4.212070  -0.239437  2.003759  4.243942
# TMF         62.0  7.607841  7.315098  -8.068232  2.016319  8.009827
# SPXL        62.0  2.816064  9.707736 -17.125983 -4.553721  5.819476
#
#                  75%        max      shrp   drawdown
# Portfolio   9.321825  14.783688  1.270534   2.945663
# TMF        12.941174  23.599407  1.017235   9.589677
# SPXL       10.167973  17.117340  0.272916  19.502869

# %%
quote.setup_mask(['EDV', 'VUG'])
quote.find_optimal_ratio(period, 2)
# Out:
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ({'EDV': 0.55, 'VUG': 0.45}, 2.5998, 1.604)

# %%
# %pylab inline
quote.setup_mask(['EDV', 'VUG'])
quote.graph(period, {'EDV': 0.55, 'VUG': 0.45})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std       min       25%       50%       75%  \
# Portfolio   62.0  2.581337  1.626169  0.265712  1.181572  2.191686  3.877921
# EDV         62.0  3.525348  3.246951 -4.006690  1.270460  3.834014  6.016200
# VUG         62.0  1.478650  3.777936 -6.918439 -1.319242  2.525938  4.515680
#
#                  max      shrp  drawdown
# Portfolio   6.076547  1.484883  1.221713
# EDV        10.713052  1.034411  4.608950
# VUG         7.104458  0.347275  8.023383

# %%
quote.setup_mask(['VGLT', 'VOO'])
quote.find_optimal_ratio(period, 2)
# Out:
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ({'VGLT': 0.6, 'VOO': 0.4}, 2.0349, 1.346)

# %%
# %pylab inline
quote.setup_mask(['VGLT', 'VOO'])
quote.graph(period, {'VGLT': 0.6, 'VOO': 0.4})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std       min       25%       50%       75%  \
# Portfolio   62.0  2.014056  1.356878  0.178047  0.873835  1.517762  3.267881
# VGLT        62.0  2.630217  2.335788 -2.477585  0.887118  2.815186  4.349756
# VOO         62.0  1.125795  3.212175 -5.753066 -1.202248  2.154030  3.582117
#
#                 max      shrp  drawdown
# Portfolio  4.913611  1.361500  0.898334
# VGLT       7.546680  1.054698  3.096044
# VOO        5.703838  0.298591  6.639516
