# %%
from app.analysis import Quote
horizon, period = 60, 21
quote = Quote(['TMF', 'SPXL', 'EDV', 'VUG', 'VGLT', 'VOO'], horizon)

# %%
quote.statistics(period)
# Out:
#          21-len    21-mean     21-std   21-shrp   drawdown
# Symbols
# VGLT         21   4.523954   1.500859  2.903195   1.634913
# TMF          21  13.491554   4.889101  2.725427   5.014042
# EDV          21   5.942246   2.191938  2.634920   2.610604
# VOO          21   1.724820   3.380690  0.460898   6.639516
# SPXL         21   4.568898  10.301713  0.427330  19.425840
# VUG          21   1.629595   3.820180  0.382947   7.939314

# %%
quote.setup_mask(['TMF', 'SPXL'])
quote.find_optimal_ratio(period)
# Out:
# ({'TMF': 0.71, 'SPXL': 0.29}, 10.9151, 2.061, 5.2152)

# %%
# %pylab inline
quote.setup_mask(['TMF', 'SPXL'])
quote.graph(period, {'TMF': 0.71, 'SPXL': 0.29})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count       mean        std        min        25%        50%  \
# Portfolio   21.0  10.889372   2.300421   6.381652   8.940987  10.904634
# TMF         21.0  13.491554   4.889101   1.334666  12.177981  14.006675
# SPXL        21.0   4.568898  10.301713 -17.125983  -0.183787   5.887284
#
#                  75%        max      shrp   drawdown
# Portfolio  11.853815  15.918532  4.661192   2.732405
# TMF        15.649751  23.599407  2.725427   5.014042
# SPXL        9.648939  24.313419  0.427330  19.425840

# %%
quote.setup_mask(['EDV', 'VUG'])
quote.find_optimal_ratio(period)
# Out:
# ({'EDV': 0.68, 'VUG': 0.32}, 4.5463, 0.9236, 4.742)

# %%
# %pylab inline
quote.setup_mask(['EDV', 'VUG'])
quote.graph(period, {'EDV': 0.68, 'VUG': 0.32})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std       min       25%       50%       75%  \
# Portfolio   21.0  4.570290  0.967611  2.558477  3.890717  4.627110  5.116786
# EDV         21.0  5.942246  2.191938  0.401792  5.258639  6.296678  6.815254
# VUG         21.0  1.629595  3.820180 -6.918439  0.224496  2.440121  3.993647
#
#                  max      shrp  drawdown
# Portfolio   6.576156  4.551025  1.069957
# EDV        10.713052  2.634920  2.610604
# VUG         7.882126  0.382947  7.939314

# %%
quote.setup_mask(['VGLT', 'VOO'])
quote.find_optimal_ratio(period)
# Out:
# ({'VGLT': 0.73, 'VOO': 0.27}, 3.757, 0.6574, 5.4618)

# %%
# %pylab inline
quote.setup_mask(['VGLT', 'VOO'])
quote.graph(period, {'VGLT': 0.73, 'VOO': 0.27})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std       min       25%       50%       75%  \
# Portfolio   21.0  3.765775  0.686474  2.339193  3.144275  3.739415  4.093957
# VGLT        21.0  4.523954  1.500859  0.519552  4.124250  4.682800  5.177930
# VOO         21.0  1.724820  3.380690 -5.753066  0.309997  2.246680  3.469173
#
#                 max      shrp  drawdown
# Portfolio  5.262631  5.242891  0.806580
# VGLT       7.546680  2.903195  1.634913
# VOO        7.901478  0.460898  6.639516
