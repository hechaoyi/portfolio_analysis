# %%
# %pylab inline
from wallet.util.analysis import Analysis
categories = ['Equities,Domestic,Large-Cap',
              'Bonds,Domestic,Government', 'Bonds,Domestic,MultiAssets (Bond Funds)']
previous = ['QUAL','QQQ','VCLT','SCHG','SPYV']
ana = Analysis.from_funds(50, categories=categories, max_exp=.2, additions=previous + ['SPXL','TMF'])
print(ana)
ana.screen().head(20)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# from 2019-10-16 to 2020-01-03 - 88 symbols
#          count      mean       std       min       25%       50%       75%  \
# Symbols
# QUAL      50.0  0.171391  0.131128 -0.184970  0.121220  0.195958  0.274212
# OEF       50.0  0.178859  0.148716 -0.235562  0.065894  0.203705  0.288916
# USMC      50.0  0.150509  0.127567 -0.193810  0.075752  0.173227  0.240633
# GSLC      50.0  0.151952  0.130399 -0.219060  0.077293  0.182235  0.250822
# IWY       50.0  0.194797  0.169926 -0.260405  0.102298  0.225628  0.321491
# VONG      50.0  0.186456  0.165016 -0.267468  0.103587  0.214628  0.322835
# SCHG      50.0  0.188125  0.172197 -0.275532  0.079997  0.206840  0.312815
# IWF       50.0  0.185205  0.169679 -0.287902  0.102557  0.210837  0.320750
# IVW       50.0  0.160798  0.150862 -0.244271  0.068669  0.158726  0.279113
# DGRO      50.0  0.147860  0.138176 -0.257321  0.080688  0.162620  0.240733
# ...

# %%
print(ana)
ana.optimize_iteration([40, 30, 30], additions=previous)
# Out:
# from 2019-10-16 to 2020-01-03 - 35 symbols
# ([(0.8765, {'IUSV': 1}),
#   (0.9493, {'IUSV': 0.7432, 'QQQ': 0.2568}),
#   (0.9746, {'IWD': 0.7955, 'QQQ': 0.2045}),
#   (1.095, {'IVE': 0.5531, 'MTUM': 0.4469}),
#   (1.1026, {'IUSG': 0.637, 'IVE': 0.363}),
#   (1.1044, {'GSLC': 1}),
#   (1.1099, {'IUSG': 0.2991, 'IWD': 0.2484, 'IUSV': 0.2159, 'MTUM': 0.2366}),
#   (1.1144, {'MTUM': 0.2204, 'IUSG': 0.3546, 'IVE': 0.425}),
#   (1.1233, {'VONG': 0.2091, 'USMC': 0.7909}),
#   (1.1248, {'SCHG': 0.5687, 'IWD': 0.4313}),
#   (1.1286, {'SCHG': 0.6301, 'SPYV': 0.3699}),
#   (1.1321, {'VONG': 0.703, 'SPYV': 0.297}),
#   (1.1329, {'SPYV': 0.2739, 'IWY': 0.7261}),
#   (1.1329, {'USMC': 0.6034, 'GSLC': 0.3966}),
#   (1.1359, {'USMC': 0.7833, 'VTV': 0.2167}),
#   (1.1431, {'VONG': 0.3222, 'USMC': 0.4774, 'SPYV': 0.2004}),
#   (1.1493, {'OEF': 1}),
#   (1.1506, {'IWY': 0.6181, 'VTV': 0.3819}),
#   (1.1506, {'VONG': 0.5924, 'VTV': 0.4076}),
#   (1.152, {'SCHG': 0.5351, 'VTV': 0.4649}),
# ...

# %%
ana.graph({'USMC': 18,
      'VCLT': 10,
      'MGV': 12,
      'SCHG': 16,
      'VTV': 14,
      'SPYV': 8,
      'IWY': 22}) #3,1
# Out:
#            count      mean       std       min       25%       50%       75%  \
# Portfolio   50.0  0.158724  0.126409 -0.199080  0.094960  0.185461  0.248919
# USMC        50.0  0.150509  0.127567 -0.193810  0.075752  0.173227  0.240633
# IWY         50.0  0.194797  0.169926 -0.260405  0.102298  0.225628  0.321491
# SCHG        50.0  0.188125  0.172197 -0.275532  0.079997  0.206840  0.312815
# MGV         50.0  0.156093  0.149484 -0.273734  0.082379  0.153979  0.279877
# VTV         50.0  0.151636  0.149245 -0.272095  0.074099  0.160032  0.275244
# SPYV        50.0  0.164549  0.176282 -0.328908  0.088639  0.166523  0.304560
# VCLT        50.0  0.052727  0.163312 -0.470365 -0.028905  0.076287  0.144970
#
#                 max      shrp      yield      down      skew
# Portfolio  0.364828  1.192850   8.419778  1.619953 -1.110840
# USMC       0.360604  1.117631   7.738460  1.536572 -0.668528
# IWY        0.445982  1.099658  10.164307  1.948885 -0.930695
# ...

# %%
ana.graph({'BSV': 31, 'QUAL': 9, 'QQQ': 18, 'VCLT': 12, 'SCHG': 19, 'SPYV': 11})
# Out:
#            count      mean       std       min       25%       50%       75%  \
# QUAL        50.0  0.171391  0.131128 -0.184970  0.121220  0.195958  0.274212
# SCHG        50.0  0.188125  0.172197 -0.275532  0.079997  0.206840  0.312815
# SPYV        50.0  0.164549  0.176282 -0.328908  0.088639  0.166523  0.304560
# QQQ         50.0  0.212308  0.290745 -0.315330  0.000000  0.224959  0.388961
# Portfolio   50.0  0.117870  0.215802 -0.149789  0.000000  0.117067  0.174722
# VCLT        50.0  0.052727  0.163312 -0.470365 -0.028905  0.076287  0.144970
# BSV         50.0  0.007195  0.033270 -0.083523 -0.011789  0.008601  0.036553
#
#                 max      shrp      yield      down      skew
# QUAL       0.368906  1.246530   9.063124  1.768750 -0.877829
# SCHG       0.444786  1.046414   9.965729  1.923500 -0.768725
# SPYV       0.545858  0.888419   8.903511  2.016944 -0.363369
# QQQ        1.611126  0.702925  11.191647  2.247127  2.095449
# ...

# %%
ana.graph({'SPXL': 60, 'TMF': 40})
# Out:
#            count      mean       std       min       25%       50%       75%  \
# SPXL        50.0  0.462933  0.424594 -0.758645  0.240118  0.557537  0.754634
# Portfolio   50.0  0.255852  0.393459 -0.653225  0.050505  0.298354  0.525683
# TMF         50.0 -0.102559  0.907979 -2.492189 -0.555547 -0.135181  0.589151
#
#                 max      shrp      yield       down      skew
# SPXL       1.114034  1.071604  26.007578   5.656110 -1.056189
# Portfolio  0.899082  0.630092  14.672100   4.003951 -0.502212
# TMF        1.756826 -0.121694  -2.331117  12.563844 -0.340491
