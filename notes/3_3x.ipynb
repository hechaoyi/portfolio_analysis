# %%
from app.analysis import Quote
horizon, period = 120, 21
quote = Quote(['TMF', 'UPRO', 'TLT', 'VOO'], horizon)

# %%
quote.statistics(period)
# Out:
#          21-len   21-mean    21-std   21-shrp   drawdown
# Symbols
# TLT          62  2.775985  2.417971  1.079135   3.224333
# TMF          62  7.971061  7.508520  1.039405   9.589672
# VOO          62  0.868147  3.043293  0.230501   6.639509
# UPRO         62  1.939159  9.146147  0.193797  19.546274

# %%
quote.setup_mask(['TMF', 'UPRO'])
quote.find_optimal_ratio(period, 5)
# Out:
#      fun: 15.963238203480229
#      jac: array([31.92748272, 31.92517638])
#  message: 'Optimization terminated successfully.'
#     nfev: 8
#      nit: 2
#     njev: 2
#   status: 0
#  success: True
#        x: array([0.5641166, 0.4358834])
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# ({'TMF': 0.5641165980252176, 'UPRO': 0.43588340197478237}, 5.3419, 3.9954)

# %%
quote.setup_mask(['TLT', 'VOO'])
quote.find_optimal_ratio(period, 2)
# Out:
#      fun: 1.7545445095859424
#      jac: array([3.50872104, 3.50958765])
#  message: 'Optimization terminated successfully.'
#     nfev: 8
#      nit: 2
#     njev: 2
#   status: 0
#  success: True
#        x: array([0.57525486, 0.42474514])
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ({'TLT': 0.5752548649368106, 'VOO': 0.42474513506318945}, 1.9656, 1.3246)

# %%
quote.setup_mask(['TMF', 'VOO'])
quote.find_optimal_ratio(period, 2)
# Out:
#      fun: 4.262099478960783
#      jac: array([8.53741252, 8.52010459])
#  message: 'Optimization terminated successfully.'
#     nfev: 8
#      nit: 2
#     njev: 2
#   status: 0
#  success: True
#        x: array([0.23657935, 0.76342065])
# /Users/chaoyi/.local/share/virtualenvs/portfolio_analysis-bdMx2S3t/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ({'TMF': 0.23657935059109275, 'VOO': 0.7634206494089072}, 2.5486, 2.0645)

# %%
quote.setup_mask(['TLT', 'UPRO'])
quote.find_optimal_ratio(period, 2)
# Out:
#      fun: 3.145800641793634
#      jac: array([6.29147425, 6.29229689])
#  message: 'Optimization terminated successfully.'
#     nfev: 8
#      nit: 2
#     njev: 2
#   status: 0
#  success: True
#        x: array([0.84519071, 0.15480929])
# ({'TLT': 0.8451907146468113, 'UPRO': 0.15480928535318872}, 2.6464, 1.7736)

# %%
# %pylab inline
quote.setup_mask(['TMF', 'UPRO'])
quote.graph(period, {'TMF': 0.56, 'UPRO': 0.44})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std        min       25%       50%  \
# Portfolio   62.0  5.168864  4.122030  -0.736769  1.480578  3.916449
# TMF         62.0  7.971061  7.508520  -8.068234  2.016323  8.914756
# UPRO        62.0  1.939159  9.146147 -17.186619 -4.650871  4.915548
#
#                  75%        max      shrp   drawdown
# Portfolio   8.907914  14.396268  1.213528   3.347684
# TMF        14.241274  23.599406  1.039405   9.589672
# UPRO        8.696673  16.996325  0.193797  19.546274

# %%
# %pylab inline
quote.setup_mask(['TLT', 'VOO'])
quote.graph(period, {'TLT': 0.58, 'VOO': 0.42})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std       min       25%       50%       75%  \
# Portfolio   62.0  1.958072  1.338226  0.077673  0.791620  1.541049  3.190685
# TLT         62.0  2.775985  2.417971 -2.582910  0.929805  3.145745  4.799149
# VOO         62.0  0.868147  3.043293 -5.753061 -1.202248  1.893828  3.118517
#
#                 max      shrp  drawdown
# Portfolio  4.924321  1.338642  1.215910
# TLT        7.624531  1.079135  3.224333
# VOO        5.703839  0.230501  6.639509

# %%
# %pylab inline
quote.setup_mask(['TMF', 'VOO'])
quote.graph(period, {'TMF': 0.24, 'VOO': 0.76})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std       min       25%       50%        75%  \
# Portfolio   62.0  2.586748  2.102723 -0.586752  0.701971  2.299265   4.419354
# TMF         62.0  7.971061  7.508520 -8.068234  2.016323  8.914756  14.241274
# VOO         62.0  0.868147  3.043293 -5.753061 -1.202248  1.893828   3.118517
#
#                  max      shrp  drawdown
# Portfolio   7.138502  1.150927  2.166401
# TMF        23.599406  1.039405  9.589672
# VOO         5.703839  0.230501  6.639509

# %%
# %pylab inline
quote.setup_mask(['TLT', 'UPRO'])
quote.graph(period, {'TLT': 0.85, 'UPRO': 0.15})
# Out:
# Populating the interactive namespace from numpy and matplotlib
#            count      mean       std        min       25%       50%       75%  \
# Portfolio   62.0  2.586789  1.789938  -0.185337  1.124673  2.194056  4.134670
# TLT         62.0  2.775985  2.417971  -2.582910  0.929805  3.145745  4.799149
# UPRO        62.0  1.939159  9.146147 -17.186619 -4.650871  4.915548  8.696673
#
#                  max      shrp   drawdown
# Portfolio   6.540988  1.352071   1.856238
# TLT         7.624531  1.079135   3.224333
# UPRO       16.996325  0.193797  19.546274
